# %% [markdown]
# # API Practice

# %%
# import libraries
import pandas as pd
import requests

# %%
# Read in the Movies.csv to find the movies with missing values
movies_df = pd.read_csv("D:\Learning\Portfolio\Movie Python Project\\movies.csv")

# %%
# Find movies with missing data in any column
missing_data_movies = movies_df[movies_df.isnull().any(axis=1)]["name"].tolist()

# Remove any potential duplicates
unique_missing_movies = list(set(missing_data_movies))

print("Movies with missing data (unique):", unique_missing_movies)
# Out:
# Movies with missing data (unique): ['Blame It on Rio', 'Trick or Treat', 'Short Cuts', 'The Guilty', "The Hairdresser's Husband", 'Loveless', "Bennett's War", 'Calvary', "Summer '03", 'Testament', 'The Silence', 'Career Opportunities', 'Oci ciornie', 'Time Walker', 'Kiss of the Spider Woman', 'Point of No Return', 'Starred Up', 'Nowhere Boy', 'Diva', 'Free Fire', 'Kicking and Screaming', 'Water', 'House of Flying Daggers', 'Taking Care of Business', 'Cliffs of Freedom', 'Sincerely Charlotte', 'De De Pyaar De', 'Maelstrom', 'In a World...', 'Chattahoochee', 'Shiloh', 'Happy Together', 'Miami Blues', 'Jung on zo', 'The Bear', 'The Blind Swordsman: Zatoichi', 'The Minus Man', 'Anthropoid', 'Mark Felt: The Man Who Brought Down the White House', 'Ed Gein', 'Ernest Scared Stupid', 'The Exorcist III', 'Trial by Fire', 'Roll Bounce', 'Ong-Bak: The Thai Warrior', 'State and Main', 'Body Heat', 'Her Alibi', 'Anna', 'A Private Function', '360', 'The Baader Meinhof Complex', 'D3: The Mighty Ducks', 'Homework', 'Lakshya', 'Rhapsody in August', 'Pinocchio', 'Evangelion: 1.0 You Are (Not) Alone', 'Luka Chuppi', 'Volver', 'Gang Related', 'Breach', 'Red Cliff', 'The Crying Game', "It's My Turn", 'Rosencrantz & Guildenstern Are Dead', 'Making Mr. Right', 'Three... Extremes', 'Crack House', 'Youth', 'Velvet Goldmine', 'Love Crimes', 'Meet the Browns', 'Airheads', "Ain't Them Bodies Saints", 'Local Hero', 'Goldstone', 'Black Sheep', 'Michael', 'The Chorus', 'Bright Young Things', 'The Emerald Forest', 'Pump Up the Volume', 'My Demon Lover', 'Dhoom', 'Complete Unknown', 'Spriggan', 'Furie', 'Three Men and a Little Lady', 'Body Shots', 'Blue Chips', 'Willy/Milly', 'Some Kind of Wonderful', 'Milk Money', 'Rich and Famous', 'Great Expectations', 'Kissing a Fool', 'Operation Dumbo Drop', 'The Stanford Prison Experiment', 'Le Dîner de Cons', 'Once Upon a Time in China III', "The Blackcoat's Daughter", "It's Just Us", 'The Garden', 'My Twentieth Century', 'Jury Duty', 'Reform School Girls', 'Making the Grade', 'Sexy Beast', 'The Wind Will Carry Us', 'The Protector', 'The Addiction', 'Sommersby', 'Nathalie...', 'Lock, Stock and Two Smoking Barrels', 'Black Death', "The Butcher's Wife", 'Un Coeur en Hiver', '24 Hour Party People', 'Dorm Daze', 'Morvern Callar', 'Family Business', 'Still Crazy', 'Exposed', 'Joshua', 'Benny & Joon', 'Electric Dreams', 'Casual Sex?', 'Rooftops', 'Nelly & Monsieur Arnaud', 'Coming Soon', 'La fille sur le pont', 'My Beautiful Laundrette', 'Tristan + Isolde', 'El Coyote', 'The Invitation', 'Madhouse', 'Triumph of the Spirit', 'Heartbreakers', 'Subway', "Nobody's Fool", 'Mommy', 'Burglar', 'Maxie', 'Care Bears Movie II: A New Generation', 'The Quake', 'Shirley Valentine', 'The Vanishing', 'The Doctor and the Devils', 'Visiting Hours', 'Open Hearts', 'Creature', "Who's Harry Crumb?", 'Caché (Hidden)', 'The Day of the Beast', 'Amazon Women on the Moon', 'The Krays', 'The Adventures of Priscilla, Queen of the Desert', 'The Inkwell', 'Eat Drink Man Woman', 'The Lighthouse', 'Wildlife', 'The Mighty Quinn', 'Chasers', 'The Big Blue', 'La Cage aux Folles 3: The Wedding', 'Ek Ladki Ko Dekha Toh Aisa Laga', 'The Housemaid', 'Tell No One', 'Bad Blood', 'Promised Land', 'Addicted to Love', 'Night Game', 'Bloodsport 2', 'The Woodsman', 'Hanky Panky', 'P.O.W. the Escape', 'Shout', 'My Girl 2', 'Malena', '42nd Street: The Musical', 'Water Lilies', 'Land and Freedom', 'Double Lover', 'Monkey Trouble', 'Mad Love', 'The Amazing Panda Adventure', 'I Shot Andy Warhol', 'La traviata', 'My Favorite Year', 'Underdog', 'Man, Woman and Child', 'Border', 'Heavy', 'Fraternity Vacation', 'Serious Moonlight', 'Paternity', 'I Saw the Devil', 'The Seventh Sign', 'Breakfast on Pluto', 'Ed and His Dead Mother', 'Before the Fall', 'The Flower of My Secret', 'Definitely, Maybe', 'Bent', 'No Manches Frida 2', 'American Ninja 3: Blood Hunt', 'The Green Butchers', 'Lagaan: Once Upon a Time in India', 'Cyclone', '7 Days in Entebbe', 'Europa', 'Kikujiro', 'Jeepers Cr ...

# %%
# storing api key for TMDB
api_key = "b0cb9ab8feac8f1febed37016dd0f526"

# %%
# Empty list for storing missing movies
movie_data = []

# %%
# Using the TMDB Api to find data for the missing movie values
# Using unique_missing_movies to iterate through missing values

for movie_title in unique_missing_movies:
    try:
        # Search for the movie using the title
        search_url = f"https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={movie_title}"
        search_response = requests.get(search_url)
        search_response.raise_for_status()  # Raise error for non-200 status codes
        search_data = search_response.json()

        # Check if any results were found
        if search_data["results"]:
            movie_id = search_data["results"][0]["id"]  # Get the ID of the first result

            # Fetch movie details using the ID
            detail_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}"
            detail_response = requests.get(detail_url)
            detail_response.raise_for_status()
            movie_data.append(detail_response.json())

        else:
            print(f"Movie '{movie_title}' not found.")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for movie '{movie_title}': {e}")

# Create a Pandas DataFrame from the collected movie data
missing_df = pd.DataFrame(movie_data)

# Show Dataframe
missing_df
# Out:
# Error fetching data for movie 'The Way': ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Movie 'Tee em el' not found.
# Movie 'In God We Trust (or Gimme That Prime Time Religion)' not found.
# Movie 'Geolkapseu' not found.
#       adult                     backdrop_path belongs_to_collection    budget  \
# 0     False  /zYeYZuqXuB2nfIR4zfKhaDWHeF6.jpg                  None   9000000
# 1     False  /zoL7dO6Uw8wOtkhfrwryevQudSK.jpg                  None         0
# 2     False  /a0OjGWE9ru1OlKLBujbz3mAYYxU.jpg                  None         0
# 3     False  /q83fNIvLYFYZ3SfRUoBACciOzMX.jpg                  None         0
# 4     False  /bkyugLf910U8TahWO9ChTunSMfU.jpg                  None         0
# ...     ...                               ...                   ...       ...
# 2222  False  /fTPi0tXFf4BSDDdf7J9pq5V9XyG.jpg                  None         0
# 2223  False  /3CeWGZjH9jSU16sZFnxMHMiP7zS.jpg                  None         0
# 2224  False  /sEl2Z5m3KgmAUMLaNJG8gQpVPIb.jpg                  None         0
# 2225  False  /gHtdmi1ZjwdOVcg7OExpLtfkDJF.jpg                  None  10000000
# 2226  False  /dcoqmFVrcPw2lTcuJOxsAmZOG9n.jpg                  None         0
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 1     [{'id': 12, 'name': 'Adventure'}, {'id': 9648,...
# 2     [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...                                                 ...
# 2222  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 2223  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 2224  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2225  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 2226  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                                homepage       id     imdb_id  \
# 0                                                          14347   tt0086973
# 1     https://www.warnerbros.com/movies/trick-or-tre...  1015724  tt21919270
# 2                                                            695   tt0108122
# 3                https://www.netflix.com/title/81345983   567748   tt9421570
# 4                                                          11796   tt0100112
# ...                                                 ...      ...         ...
# 2222     https://www.troma.com/films/def-by-temptation/    71853   tt0099395
# 2223                                                      140605   tt0088895
# 2224                                                       81824   tt0091310
# 2225                                                        2212   tt0119791
# 2226                                                      556271   tt6988116
#
#      original_language              original_title  ... release_date  \
# 0                   en             Blame It on Rio  ...   1984-02-17
# 1                   en  Trick or Treat Scooby-Doo!  ...   2022-10-04
# 2                   en                  Short Cuts  ...   1993-09-05
# 3                   en                  The Guilty  ...   2021-09-24
# 4                   fr     Le Mari de la coiffeuse  ...   1990-10-03
# ...                ...                         ...  ...          ...
# 2222                en           Def by Temptation  ...   1990-03-23
# 2223                en                Certain Fury  ...   1985-03-01
# 2224                en        Just Between Friends  ...   1986-03-21
# 2225                en                  Nightwatch  ...   1997-01-31
# 2226                hi                        कलंक  ...   2019-04-17
#
#        revenue runtime                                   spoken_languages  \
# 0     18644570     100  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1            0      78  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2      6110979     188  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3            0      91  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4            0      82  [{'english_name': 'Arabic', 'iso_639_1': 'ar',...
# ...        ...     ...                                                ...
# 2222         0      95  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2223   1400000      87  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2224   1991930     110  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2225   1179002     102  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2226         0     166  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
#
#         status                                            tagline  \
# 0     Released  She's the hottest thing on the beach. She's al...
# 1     Released                                    Trick or trap?!
# 2     Released             Short Cuts raises the roof on America.
# 3     Released                                  Listen carefully.
# 4     Released
# ...        ...                                                ...
# 2222  Released            A terrifying tale of vampires and lust!
# 2223  Released  Two Academy Award Winning Stars... In the one ...
# 2224  Released  They loved. They laughed. They lied. All this ...
# 2225  Released
# 2226  Released
#
#                            title  video vote_average vote_count
# 0                Blame It on Rio  False        5.639        155
# 1     Trick or Treat Scooby-Doo!  False        7.023        173
# 2                     Short Cuts  False        7.226        545
# 3                     The Guilty  False        6.400       2447
# 4      The Hairdresser's Husband  False        6.900        192
# ...                          ...    ...          ...        ...
# 2222           Def by Temptation  False        4.833         45
# 2223                Certain Fury  False        5.200         17
# 2224        Just Between Friends  False        5.222          9
# 2225                  Nightwatch  False        6.043        370
# 2226                      Kalank  False        5.541         49
#
# [2227 rows x 25 columns]

# %%
# Inspecting the dataframe
missing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2227 entries, 0 to 2226
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  2227 non-null   bool
#  1   backdrop_path          2156 non-null   object
#  2   belongs_to_collection  236 non-null    object
#  3   budget                 2227 non-null   int64
#  4   genres                 2227 non-null   object
#  5   homepage               2227 non-null   object
#  6   id                     2227 non-null   int64
#  7   imdb_id                2218 non-null   object
#  8   original_language      2227 non-null   object
#  9   original_title         2227 non-null   object
#  10  overview               2227 non-null   object
#  11  popularity             2227 non-null   float64
#  12  poster_path            2216 non-null   object
#  13  production_companies   2227 non-null   object
#  14  production_countries   2227 non-null   object
#  15  release_date           2227 non-null   object
#  16  revenue                2227 non-null   int64
#  17  runtime                2227 non-null   int64
#  18  spoken_languages       2227 non-null   object
#  19  status                 2227 non-null   object
#  20  tagline                2227 non-null   object
#  21  title                  2227 non-null   object
#  22  video                  2227 non-null   bool
#  23  vote_average           2227 non-null   float64
#  24  vote_count             2227 non-null   int64
# dtypes: bool(2), float64(2), int64(5), object(16)
# memory usage: 404.6+ KB

# %%
#Removing unwanted columns from missing_df
missing_copy_df = missing_df.drop(['adult', 'backdrop_path','belongs_to_collection','homepage','id','imdb_id'
                              ,'original_language','original_title','overview','popularity','poster_path',
                             'spoken_languages','status','tagline','video', 'genres', 
                             'release_date', 'vote_average', 'vote_count','production_countries', 'revenue'
                            ,'production_companies', 'runtime'],axis = 1)

# %%
# Rename the title column to match the Movies column name
missing_copy_df = missing_copy_df.rename(columns = {'title': 'name'})

# %%
# Checking the changes made
missing_copy_df
# Out:
#         budget                        name
# 0      9000000             Blame It on Rio
# 1            0  Trick or Treat Scooby-Doo!
# 2            0                  Short Cuts
# 3            0                  The Guilty
# 4            0   The Hairdresser's Husband
# ...        ...                         ...
# 2222         0           Def by Temptation
# 2223         0                Certain Fury
# 2224         0        Just Between Friends
# 2225  10000000                  Nightwatch
# 2226         0                      Kalank
#
# [2227 rows x 2 columns]

# %%
# Create Copies of both the main dataframe (movies) and the edited missing values dataframe

original_df = movies_df.copy()
update_df = missing_copy_df.copy()

# %%
# check the Dataframe works
original_df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
#                               released  score      votes         director  \
# 0        June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1         July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2        June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3         July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4        July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
# ...                                ...    ...        ...              ...
# 7663  October 23, 2020 (United States)    3.1       18.0    Joseph Ebanks
# 7664  February 7, 2020 (United States)    4.7       36.0     Dusty Dukatz
# 7665         April 27, 2020 (Cameroon)    5.7       29.0     Nkanya Nkwai
# 7666   October 1, 2020 (United States)    NaN        NaN    James Randall
# 7667   August 19, 2020 (United States)    5.7        7.0     Pereko Mosia
#
#                        writer              star         country      budget  \
# 0                Stephen King    Jack Nicholson  United Kingdom  19000000.0
# 1     Henry De Vere Stacpoole    Brooke Shields   United States   4500000.0
# 2              Leigh Brackett       Mark Hamill   United States  18000000.0
# 3                Jim Abrahams       Robert Hays   United States   3500000.0
# 4          Brian Doyle-Murray       Chevy Chase   United States   6000000.0
# ...                       ...               ...             ...         ...
# 7663            Joseph Ebanks      Shannon Bond   United States      7000.0
# 7664              Lisa Huston  Michael Saquella   United States         NaN
# 7665             Lynno Lovert      Onyama Laura   United States     58750.0
# 7666            James Randall     Christina Roz   United States     15000.0
# 7667             Pereko Mosia  Siyabonga Mabaso    South Africa         NaN
#
#             gross                    company  runtime
# 0      46998772.0               Warner Bros.    146.0
# 1      58853106.0          Columbia Pictures    104.0
# 2     538375067.0                  Lucasfilm    124.0
# 3      83453539.0         Paramount Pictures     88.0
# 4      39846344.0             Orion Pictures     98.0
# ...           ...                        ...      ...
# 7663          NaN                        NaN     90.0
# 7664          NaN  Cactus Blue Entertainment     90.0
# 7665          NaN           Embi Productions      NaN
# 7666          NaN                        NaN    120.0
# 7667          NaN                PK 65 Films    102.0
#
# [7668 rows x 15 columns]

# %%
# check the Dataframe works
update_df
# Out:
#         budget                        name
# 0      9000000             Blame It on Rio
# 1            0  Trick or Treat Scooby-Doo!
# 2            0                  Short Cuts
# 3            0                  The Guilty
# 4            0   The Hairdresser's Husband
# ...        ...                         ...
# 2222         0           Def by Temptation
# 2223         0                Certain Fury
# 2224         0        Just Between Friends
# 2225  10000000                  Nightwatch
# 2226         0                      Kalank
#
# [2227 rows x 2 columns]

# %%
# Create a dictionary called update that uses name as the key and budget as the value
update = {row['name']: row['budget'] for index, row in update_df.iterrows()}

# %%
#Check update values and format
update
# Out:
# {'Blame It on Rio': 9000000,
#  'Trick or Treat Scooby-Doo!': 0,
#  'Short Cuts': 0,
#  'The Guilty': 0,
#  "The Hairdresser's Husband": 0,
#  'Loveless': 0,
#  "Bennett's War": 0,
#  'Calvary': 0,
#  "Summer '03": 0,
#  'Testament': 1500000,
#  'The Silence': 0,
#  'Career Opportunities': 6000000,
#  'Dark Eyes': 0,
#  'Time Walker': 750000,
#  'Kiss of the Spider Woman': 1250000,
#  'Point of No Return': 0,
#  'Starred Up': 0,
#  'Nowhere Boy': 0,
#  'Diva': 0,
#  'Free Fire': 7000000,
#  'Kicking and Screaming': 0,
#  'Water': 0,
#  'House of Flying Daggers': 15000000,
#  'Taking Care of Business': 14000000,
#  'Cliffs of Freedom': 0,
#  'Sincerely Charlotte': 0,
#  'De De Pyaar De': 0,
#  'Maelström': 0,
#  'In a World...': 1000000,
#  'Chattahoochee': 0,
#  'Shiloh': 0,
#  'Happy Together': 0,
#  'Miami Blues': 0,
#  'UFC Fight Night 180: Ortega vs. The Korean Zombie': 0,
#  'The Bear': 0,
#  'Zatoichi': 2500000,
#  'The Minus Man': 0,
#  'Anthropoid': 0,
#  'Mark Felt: The Man Who Brought Down the White House': 0,
#  'Ed Gein': 0,
#  'Ernest Scared Stupid': 0,
#  'The Exorcist III': 9300000,
#  'Trial by Fire': 0,
#  'Roll Bounce': 0,
#  'Ong-Bak': 1100000,
#  'State and Main': 0,
#  'Body Heat': 9000000,
#  'Her Alibi': 0,
#  'Anna': 34000000,
#  'A Private Function': 0,
#  '360': 0,
#  'The Baader Meinhof Complex': 27000000,
#  'D3: The Mighty Ducks': 0,
#  'Homework': 0,
#  'Lakshya': 4500000,
#  'Rhapsody in August': 0,
#  'Pinocchio': 2600000,
#  'Evangelion: 1.0 You Are (Not) Alone': 7000000,
#  'Luka Chuppi': 0,
#  'Volver': 12899867,
#  'Gang Related': 0,
#  'Breach': 0,
#  'Red Cliff': 80341000,
#  'The Crying Game': 3705538,
#  "It's My Turn": 0,
#  'Rosencrantz & Guildenstern Are Dead': 0,
#  'Making Mr. Right': 0,
#  'Three… Extremes': 77532,
#  'Crack House': 0,
#  'Youth': 13360000,
#  'Velvet Goldmine': 0,
#  'Love Crimes': 0,
#  'Meet the Browns': 20000000,
#  'Airheads': 0,
#  "Ain't Them Bodies Saints": 4000000,
#  'Local Hero': 4200000,
#  'Goldstone': 0,
#  'Black Sheep': 0,
#  'Michael': 20000000,
#  'The Chorus': 0,
#  'Bright Young Things': 10000000,
#  'The Emerald Forest': 0,
#  'Pump Up the Volume': 0,
#  'My Demon Lover': 0,
#  'Dhoom 3': 19500000,
#  'Complete Unknown': 0,
#  'Spriggan': 5000,
#  'Get In': 0,
#  '3 Men and a Little Lady': 0,
#  'Body Shots': 0,
#  'Blue Chips': 35000000,
#  'Willy/Milly': 0,
#  'Some Kind of Wonderful': 0,
#  'Milk Money': 0,
#  'Rich and Famous': 11500000,
#  'Great Expectations': 25000000,
#  'Kissing a Fool': 0,
#  'Operation Dumbo Drop': 0,
#  'The Stanford Prison Experiment': 0,
#  'The Dinner Game': 12500000,
#  'Once Upon a Time in China III': 0,
#  "The Blackcoat's Daughter": 0,
#  'Just the Two of Us': 6300000,
#  'The Garden': 0,
#  'My Twentieth Century': 0,
#  'Jury Duty': 0,
#  'Reform School Girls': 0,
#  'Making the Grade': 0,
#  'Sexy Beast': 5000000,
#  'The Wind Will Carry Us': 0,
#  'The Protector': 0,
#  'The Addiction': 0,
#  'Sommersby': 30000000,
#  'Nathalie: Escape from Hell': 0,
#  'Lock, Stock and Two Smoking Barrels': 1350000,
#  'Black Death': 0,
#  "The Butcher's Wife": 0,
#  'A Heart in Winter': 0,
#  '24 Hour Party People': 0,
#  'National Lampoon Presents Dorm Daze': 0,
#  'Morvern Callar': 0,
#  'Family Business': 0,
#  'Still Crazy': 0,
#  'Exposed': 0,
#  'Joshua': 0,
#  'Benny & Joon': 0,
#  'Electric Dreams': 0,
#  'Casual Sex?': 0,
#  'Rooftops': 0,
#  'Nelly and Monsieur Arnaud': 0,
#  'Coming Soon': 0,
#  'The Girl on the Bridge': 0,
#  'My Beautiful Laundrette': 860000,
#  'Tristan & Isolde': 31000000,
#  'El Coyote': 0,
#  'The Invitation': 10000000,
#  'Madhouse': 0,
#  'Triumph of the Spirit': 0,
#  'Heartbreakers': 35000000,
#  'Subway': 2000000,
#  "Nobody's Fool": 0,
#  'Mommy': 4900000,
#  'Burglar': 0,
#  'Maxie': 0,
#  'Care Bears Movie II: A New Generation': 3400000,
#  'The Quake': 6300000,
#  'Shirley Valentine': 0,
#  'The Vanishing': 0,
#  'The Doctor and the Devils': 147070,
#  'Visiting Hours': 6000000,
#  'Open Hearts': 0,
#  'Creature': 750000,
#  "Who's Harry Crumb?": 0,
#  'Caché': 8731048,
#  'The Day of the Beast': 0,
#  'Amazon Women on the Moon': 0,
#  'The Krays': 0,
#  'The Adventures of Priscilla, Queen of the Desert': 2000000,
#  'The Inkwell': 0,
#  'Eat Drink Man Woman': 0,
#  'The Lighthouse': 11000000,
#  'Wildlife': 0,
#  'The Mighty Quinn': 0,
#  'Chasers': 0,
#  'The Big Blue': 14390509,
#  'La Cage aux Folles 3: The Wedding': 0,
#  'Ek Ladki Ko Dekha Toh Aisa Laga': 0,
#  'The Housemaid': 0,
#  'Tell No One': 11700000,
#  'Bad Blood': 0,
#  'The Promised Land': 8500000,
#  'Addicted to Love': 0,
#  'Night Game': 0,
#  'Bloodsport II': 0,
#  'The Woodsman': 4000000,
#  'Hanky Panky': 14000000,
#  'P.O.W. The Escape': 0,
#  'Shout': 0,
#  'My Girl 2': 0,
#  'Malena': 0,
#  '42nd Street': 0,
#  'Water Lilies': 0,
#  'Land and Freedom': 0,
#  'Double Lover': 7110000,
#  'Monkey Trouble': 0,
#  'Mad Love': 0,
#  'The Amazing Panda Adventure': 0,
#  'I Shot Andy Warhol': 0,
#  'La Traviata': 0,
#  'My Favorite Year': 7900000,
#  'Underdog': 25000000,
#  'Man, Woman and Child': 0,
#  'Border': 0,
#  'Heavy': 0,
#  'Fraternity Vacation': 0,
#  'Serious Moonlight': 0,
#  'Paternity': 9000000,
#  'I Saw the Devil': 6000000,
#  'The Seventh Sign': 0,
#  'Breakfast on Pluto': 0,
#  'Ed and His Dead Mother': 0,
#  'Before the Fall': 4500000,
#  'The Flower of My Secret': 0,
#  'Definitely, Maybe': 0,
#  'Bent': 0,
#  'No Manches Frida 2': 5000000,
#  'American Ninja 3: Blood Hunt': 0,
#  'The Green Butchers': 0,
#  'Lagaan: Once Upon a Time in India': 5200000,
#  'Cyclone': 0,
#  '7 Days in Entebbe': 0,
#  'Europa': 0,
#  'Kikujiro': 0,
#  'Jeepers Creepers 3': 6200000,
#  'Zindagi Na Milegi Dobara': 7700000,
#  'D.O.A.': 0,
#  'Kahaani': 1200000,
#  "I Can't Think Straight": 0,
#  'Rumpelstiltskin': 0,
#  'Monsieur Hire': 0,
#  'Lion of the Desert': 35000000,
#  'The Princess and the Frog': 105000000,
#  'Horns': 0,
#  'Clockwise': 0,
#  'Tetsuo II: Body Hammer': 125000,
#  'Fearless': 20000000,
#  'Silent Night, Deadly Night Part 2': 250000,
#  "That's Life!": 0,
#  'Sixty Minutes': 0,
#  'Severance': 0,
#  'Goodbye Christopher Robin': 0,
#  'Blue Steel': 0,
#  'The Inner Circle': 0,
#  'The Farewell': 250300,
#  'Meet the Robinsons': 150000000,
#  'A Good Woman': 0,
#  'Raw': 0,
#  'Wired': 0,
#  'Something to Talk About': 30000000,
#  'Palmetto': 0,
#  'Eureka': 0,
#  'Song of the Sea': 0,
#  "Can't Buy Me Love": 1800000,
#  'A Field in England': 300000,
#  '29th Street': 0,
#  "Grandma's Boy": 5000000,
#  'Thelma': 5700000,
#  "Rustlers' Rhapsody": 5500000,
#  'The Untamed': 0,
#  'Prancer': 0,
#  "Prizzi's Honor": 0,
#  'Serial': 0,
#  'The Heavenly Kid': 0,
#  'Aloha Surf Hotel': 0,
#  'The Edge of Love': 0,
#  'Primeval': 0,
#  'Boiling Point': 0,
#  'Zebrahead': 0,
#  'Far from Home: The Adventures of Yellow Dog': 0,
#  'The Wall': 3000000,
#  'The Overnight': 0,
#  'Arthur 2: On the Rocks': 0,
#  'Last Exit to Brooklyn': 0,
#  'Mary Magdalene': 0,
#  'The War': 0,
#  'Cherry 2000': 10000000,
#  'First Kid': 0,
#  'Taxi': 8700000,
#  'Ne Zha': 20000000,
#  'The General': 750000,
#  'The Truth About Cats & Dogs': 0,
#  'An American Tail: Fievel Goes West': 0,
#  'Godard Mon Amour': 12840746,
#  'Undertow': 0,
#  'Turtle Diary': 0,
#  'The Star Maker': 0,
#  'Deadtime Stories': 0,
#  'Ghoulies': 5500000,
#  'La Haine': 2600000,
#  'The Adventures of Buckaroo Banzai Across the 8th Dimension': 0,
#  'Tucker and Dale vs. Evil': 5000000,
#  "Wild Hearts Can't Be Broken": 0,
#  'The Playboys': 0,
#  'Big Business': 0,
#  'Terror Firmer': 0,
#  'Crimes of Passion': 0,
#  'Shy People': 0,
#  'White Star': 0,
#  'Playing for Keeps': 35000000,
#  'Colonel Redl': 0,
#  'Men at Work': 9000000,
#  'Swing Kids': 0,
#  'My Father the Hero': 0,
#  'The Dressmaker': 11930000,
#  'Forever Young': 0,
#  'A Private War': 0,
#  'Amityville: The Awakening': 12000000,
#  'Isle of Dogs': 62770198,
#  'Play the Flute': 0,
#  'The Chase': 26000000,
#  'Intervista': 0,
#  'Easy Virtue': 0,
#  'Au Revoir les Enfants': 0,
#  'Your Name.': 0,
#  'The Fly II': 16500000,
#  'The Browning Version': 0,
#  'Ichi the Killer': 1400010,
#  'Wonderstruck': 7000000,
#  'Beautiful Thing': 0,
#  'Volunteers': 10000000,
#  'Class Reunion': 0,
#  'The Wild Life': 0,
#  'Mi Vida Loca': 0,
#  '976-EVIL': 0,
#  'Suburbia': 0,
#  'Nymphomaniac: Vol. II': 0,
#  'Exterminator 2': 0,
#  "Love Don't Co$t a Thing": 0,
#  'State of Play': 60000000,
#  'Student of the Year 2': 0,
#  'The Man in the Moon': 1237669,
#  'The Lobster': 4000000,
#  'Truly Madly Deeply': 0,
#  "Don't Worry, He Won't Get Far on Foot": 3500000,
#  'Nowhere in Africa': 0,
#  'Wanted: Dead or Alive': 0,
#  'The Foot Fist Way': 79000,
#  'Stryker': 0,
#  'Party Line': 0,
#  'What if...': 0,
#  'Head Office': 0,
#  'Faith, Hope & Love': 0,
#  'Species II': 35000000,
#  'Official Secrets': 0,
#  'B.A.P.S': 10000000,
#  'Muppet Treasure Island': 31000000,
#  'The Hunter': 0,
#  'High Life': 8933400,
#  'Angels Crest': 0,
#  'Dennis the Menace': 35000000,
#  'The Odd Couple II': 0,
#  'Sylvester': 0,
#  'House Party 3': 0,
#  'Unfinished Song': 0,
#  'Humanity': 0,
#  'Possession': 0,
#  'Return to Paradise': 0,
#  'Last Dance': 0,
#  'The Daughter': 0,
#  "Cheech & Chong's Next Movie": 0,
#  'Das Boot': 14000000,
#  'I Ought to Be in Pictures': 0,
#  'Great Balls of Fire!': 17000000,
#  'Irma Vep': 0,
#  'Taste of Cherry': 0,
#  'Their Finest': 11795877,
#  'Square Dance': 0,
#  'CURE!': 0,
#  'The Best Intentions': 0,
#  'The Souvenir': 0,
#  'Greenfingers': 0,
#  'Merry Christmas, Mr. Lawrence': 0,
#  'House II: The Second Story': 3000000,
#  'Secret Things': 0,
#  "Tyler Perry's The Family That Preys": 15000000,
#  'BPM (Beats per Minute)': 6600000,
#  'Raise the Titanic': 36000000,
#  'Graduation Day': 0,
#  'Wrongfully Accused': 0,
#  'Beau Travail': 0,
#  'Palindromes': 0,
#  'The Piano Teacher': 3000000,
#  'The Inbetweeners Movie': 4478250,
#  'The Best of Youth': 0,
#  'The Locusts': 0,
#  'Withnail & I': 0,
#  'Take Me': 0,
#  'Queen Margot': 0,
#  'Butter': 0,
#  'The Last Emperor': 23000000,
#  'Heaven Help Us': 0,
#  'Line Walker 2: Invisible Spy': 0,
#  'Mr. Nice Guy': 12700000,
#  'Fatal Instinct': 0,
#  'The Allnighter': 0,
#  'It Takes Two': 19474589,
#  'The Little Drummer Girl': 0,
#  'Werckmeister Harmonies': 0,
#  'Hardbodies 2': 0,
#  'Echo Park': 0,
#  'Strange Invaders': 0,
#  'Wagons East!': 0,
#  'Longshot': 0,
#  'A Handful of Dust': 0,
#  'Now and Then': 12000000,
#  'The Babysitters': 0,
#  'Cookie': 0,
#  'Bob Roberts': 3900000,
#  "A Summer's Tale": 0,
#  'Unlawful Entry': 23000000,
#  'Hot Pursuit': 35000000,
#  'Thanks for Sharing': 0,
#  'The Uninvited': 0,
#  'The Adventures of Mark Twain': 0,
#  'The Missionary': 0,
#  'The Wave': 0,
#  'Sex Is Comedy': 0,
#  'Dead for a Dollar': 0,
#  'Breaker Morant': 1000000,
#  "The Monkey's Mask": 0,
#  'The Castle': 786675,
#  'The Exception': 0,
#  'Bloody Sunday': 0,
#  'Hope and Glory': 0,
#  'Joshua Then and Now': 0,
#  'Beast': 0,
#  'Ae Dil Hai Mushkil': 0,
#  'Scotland, PA': 0,
#  'Delta Force 2: The Colombian Connection': 0,
#  'Richard Pryor: Live on the Sunset Strip': 0,
#  'London': 0,
#  'Behind the Mask: The Rise of Leslie Vernon': 0,
#  'Splitting Heirs': 0,
#  'I Spit on Your Grave 2': 0,
#  'Masterminds': 25000000,
#  'Lord of the Flies': 0,
#  'Manic': 0,
#  "Weekend at Bernie's": 6500000,
#  'Timebomb': 6000000,
#  'Loving Vincent': 5500000,
#  'Fool for Love': 0,
#  'Iron Eagle III': 0,
#  'The Center of the World': 0,
#  'Sour Grapes': 0,
#  'To Sleep with Anger': 0,
#  'Bed of Roses': 0,
#  'Jab We Met': 2300000,
#  'Son in Law': 0,
#  'Man Facing Southeast': 600000,
#  'Perfect Blue': 830000,
#  'The Pirates of Penzance': 0,
#  'Father of the Bride': 0,
#  'Frances Ha': 0,
#  'Nuns on the Run': 10959015,
#  'Champions': 0,
#  'Burning': 0,
#  'Daniel': 750000,
#  'Strange Magic': 0,
#  'I Stand Alone': 0,
#  'Bagdad Cafe': 0,
#  '84C MoPic': 500000,
#  'The Scent of Green Papaya': 0,
#  'Knights of the City': 0,
#  'The Skin I Live In': 13000000,
#  'Vox Lux': 7000000,
#  'Sweet Jane': 0,
#  'TerrorVision': 0,
#  'Mosquito': 0,
#  'Puberty Blues': 0,
#  'Inland Empire': 15000000,
#  'The Object of Beauty': 0,
#  'Texas Killing Fields': 0,
#  'The Whales of August': 0,
#  "Let's Go to Prison": 4000000,
#  'Cowboy Bebop: The Movie': 0,
#  'Heat and Dust': 0,
#  'The Adjuster': 1000000,
#  "I Do... Until I Don't": 0,
#  'Little Big League': 0,
#  'Joy of Sex': 5000000,
#  'A Mighty Wind': 6000000,
#  'American Pop': 0,
#  'Kill Me Three Times': 0,
#  'John Dies at the End': 1000000,
#  'Petit Con': 0,
#  'The United States of Leland': 0,
#  'An Interview with God': 0,
#  'Bliss': 0,
#  'Lucky': 0,
#  'Saga of Tanya the Evil: The Movie': 0,
#  'Lady Macbeth': 0,
#  'Hampstead': 0,
#  'The Great White Hype': 0,
#  'Madea Goes to Jail': 17500000,
#  'Bajrangi Bhaijaan': 13000000,
#  'Orphan': 20000000,
#  'The Official Story': 0,
#  'AMOS 3:5': 5000,
#  'Heart Condition': 10000000,
#  'SLC Punk': 0,
#  'The Sweeney': 3730500,
#  'Diabolique': 45000000,
#  'Downfall': 0,
#  'Taffin': 0,
#  'All Good Things': 0,
#  'The Naked Cage': 0,
#  'Just Cause': 0,
#  'Special Forces': 10000000,
#  'That Was Then... This Is Now': 0,
#  "The Girl Who Kicked the Hornet's Nest": 4000000,
#  'This Is My Life': 0,
#  'Léon: The Professional': 16000000,
#  'The Innocents': 0,
#  'Moving': 0,
#  'Blame It on the Bellboy': 0,
#  'Creator': 0,
#  'Chocolat': 25000000,
#  'Andrey Tarkovsky in Nostalghia': 0,
#  'Feast of Love': 0,
#  'Gilda Live': 0,
#  'Wildcats': 0,
#  'Close My Eyes': 0,
#  'A Dangerous Method': 15000000,
#  'A Whole New Life': 0,
#  'Tokyo!': 0,
#  'Places in the Heart': 0,
#  'Casanova': 20000000,
#  'American Anthem': 0,
#  'When a Man Loves a Woman': 0,
#  'Iron Eagle II': 0,
#  'Zapped!': 0,
#  'Rosetta': 0,
#  'Topsy-Turvy': 0,
#  'Money': 0,
#  'Skinwalkers': 0,
#  'Plump Fiction': 0,
#  'Hellraiser': 1000000,
#  'Educating Rita': 0,
#  'Breaking the Waves': 7500000,
#  'House of Angels': 0,
#  'House Arrest': 0,
#  'Tales from Earthsea': 22000000,
#  'Under the Volcano': 0,
#  'The Decline of the American Empire': 0,
#  'A Family Thing': 0,
#  'The ABCs of Death': 0,
#  "Ulysses' Gaze": 0,
#  'Temptation of Angel': 0,
#  'Black Cat, White Cat': 0,
#  'Messenger of Death': 5000000,
#  'Damned River': 0,
#  'Kinky Boots: The Musical': 0,
#  'Blue Is the Warmest Color': 4300000,
#  'The Whistleblower': 0,
#  'Trial and Error': 0,
#  'The Lonely Guy': 0,
#  'Why Do Fools Fall In Love': 0,
#  'The Deep Blue Sea': 0,
#  'Naked in New York': 0,
#  "The Handmaid's Tale": 13000000,
#  'The Visitors': 0,
#  'River of Grass': 0,
#  'Regression': 20000000,
#  'Winter People': 0,
#  'Guilty by Suspicion': 13000000,
#  'Moll Flanders': 0,
#  'The Animal Kingdom': 14500000,
#  'Compromising Positions': 6000000,
#  'A Man in Love': 0,
#  'In the Fade': 0,
#  'Starlet': 0,
#  'Uncle Boonmee Who Can Recall His Past Lives': 0,
#  'My Hero Academia: Two Heroes': 12000000,
#  'Corpo Celeste': 0,
#  'Moving Violations': 0,
#  'Place Vendôme': 0,
#  'Night Falls on Manhattan': 10000000,
#  'The Thundering Mantis': 0,
#  'Mary Shelley': 0,
#  'Stalingrad': 0,
#  'The Last American Virgin': 0,
#  'Worth Winning': 0,
#  'The Trip': 450000,
#  'Short Term 12': 1000000,
#  'The Flamingo Kid': 0,
#  'The Accidental Tourist': 0,
#  'Padmaavat': 31000000,
#  'Soul Man': 4500000,
#  'American Dreamer': 0,
#  'Where the Buffalo Roam': 0,
#  'Sex and Zen III': 0,
#  'Empire of Lust': 0,
#  'Say Anything...': 16000000,
#  'Vital Signs': 0,
#  'Jesus of Montreal': 0,
#  "Don't Tell Mom the Babysitter's Dead": 10000000,
#  'Inventing the Abbotts': 0,
#  'Still Breathing': 0,
#  'Cross Creek': 8000000,
#  'Boardinghouse': 0,
#  'The Associate': 23000000,
#  'Mr. Wrong': 0,
#  'The Least of These': 0,
#  'Devil in the Flesh': 0,
#  'This Beautiful Fantastic': 0,
#  'Turk 182!': 15000000,
#  'Suzhou River': 0,
#  'American Satan': 0,
#  'The Evening Star': 0,
#  'Camp Nowhere': 0,
#  'The Nines': 0,
#  'Ida': 2159280,
#  'Frances': 8000000,
#  'Mona Lisa': 0,
#  "White Men Can't Jump": 0,
#  'Stick It': 0,
#  'Whore': 0,
#  'A Cry in the Wild': 0,
#  'The Square': 0,
#  'American Honey': 3500000,
#  'The Duchess': 17759769,
#  'River of Death': 0,
#  'I Want to Eat Your Pancreas': 0,
#  'Passed Away': 0,
#  'Zombeavers': 0,
#  'Murder in the First': 20000000,
#  'Blow Dry': 0,
#  'Half Moon Street': 0,
#  'The Hunger': 10000000,
#  "Everybody's Fine": 0,
#  'Vincent Must Die': 4340000,
#  'True Believer': 0,
#  'Dangal': 10400000,
#  'Masked and Anonymous': 0,
#  'Lassiter': 0,
#  'Angus': 0,
#  'A Night in the Life of Jimmy Reardon': 0,
#  'Devdas': 0,
#  'Austenland': 4900000,
#  'Trading Mom': 0,
#  'The Color of Paradise': 0,
#  'Mission Mangal': 0,
#  'Sudden Death': 35000000,
#  'Quicksilver': 10000000,
#  'Breathe In': 0,
#  'Heaven Knows What': 0,
#  'S.F.W.': 0,
#  'Black Beauty': 0,
#  'Where the Boys Are': 2000000,
#  'The Little Mermaid': 297000000,
#  'Lost Angels': 0,
#  'Lantana': 0,
#  'V/H/S/2': 0,
#  'Foxfire': 0,
#  'Urban Cowboy': 10000000,
#  'The Chipmunk Adventure': 0,
#  'Hangar 18': 0,
#  'Trainspotting': 4000000,
#  'Split Image': 0,
#  'Summer School': 0,
#  'Just Before I Go': 0,
#  'Under the Cherry Moon': 0,
#  'The Doom Generation': 800000,
#  'Strictly Business': 0,
#  'The Man Who Cried': 20170000,
#  'She Devils of the SS': 0,
#  'When the Wind Blows': 0,
#  'Repossessed': 0,
#  'White Girl': 700000,
#  'Smokey and the Bandit Part 3': 9000000,
#  'Portrait of a Lady on Fire': 5740000,
#  'Pelle the Conqueror': 0,
#  'For a Lost Soldier': 0,
#  'Repentance': 5000000,
#  'Eye of the Needle': 0,
#  'Rachel Getting Married': 0,
#  'Eros': 0,
#  'Dogtooth': 0,
#  'Ingrid Goes West': 0,
#  "Betsy's Wedding": 0,
#  'First Family': 0,
#  'Maurice': 2600000,
#  'The Man From Snowy River II': 6830000,
#  'How to Get Ahead in Advertising': 0,
#  'Rebels of the Neon God': 0,
#  'Rudy': 12000000,
#  'Going All the Way': 0,
#  "Breakin'": 1200000,
#  'My Friend Dahmer': 0,
#  "The Son's Room": 0,
#  'Kaos': 0,
#  'Kill Your Darlings': 5600000,
#  'The House That Jack Built': 9800000,
#  'Asylum': 0,
#  'Out on a Limb': 11000000,
#  'Cut and Run': 0,
#  'Tales of Vesperia: The First Strike': 0,
#  'Tom and Huck': 0,
#  'Elektra Luxx': 0,
#  'A Good Old Fashioned Orgy': 0,
#  'Paris, Texas': 1750000,
#  'Madame Bovary': 0,
#  'Dreamscape': 0,
#  "I'll See You in My Dreams": 1000000,
#  'Black Sea': 0,
#  "I'm Still Here": 0,
#  'Caught': 0,
#  'Sólo con tu pareja': 0,
#  'Only the Lonely': 0,
#  'Student Bodies': 0,
#  'Never Cry Wolf': 0,
#  'The Experts': 0,
#  'Blank Check': 13000000,
#  'The Leisure Seeker': 0,
#  'Before We Go': 0,
#  'The Gods Must Be Crazy II': 7500000,
#  'The Real Blonde': 0,
#  'Naked': 0,
#  'The Hummingbird Project': 0,
#  'See You in the Morning': 0,
#  'Bend It Like Beckham': 3500159,
#  'Hyena Road': 0,
#  'Eden Lake': 12850990,
#  '31': 1500000,
#  'Here Come the Littles': 0,
#  'Romance': 0,
#  'The Intouchables': 13000000,
#  'Clouds of Sils Maria': 6600000,
#  'Kill the Messenger': 5000000,
#  "The Angels' Share": 0,
#  'My Tutor': 0,
#  'Exit': 0,
#  'Homeward Bound II: Lost in San Francisco': 0,
#  "Adam's Apples": 3700000,
#  'Just Friends': 0,
#  'Vice Squad': 0,
#  'After Dark, My Sweet': 0,
#  'The Last Black Man in San Francisco': 0,
#  'The Acid House': 900000,
#  'The King and the Mockingbird': 0,
#  'Slayground': 5000000,
#  'To Wong Foo, Thanks for Everything! Julie Newmar': 0,
#  '4 Months, 3 Weeks and 2 Days': 852510,
#  'Walk of Shame': 6000000,
#  'The Doctor': 12000000,
#  'Streets': 0,
#  'Thursday': 0,
#  'Lady Vengeance': 0,
#  'The Good Father': 0,
#  'The Counterfeiters': 0,
#  'Life with Mikey': 2000000,
#  'Greenberg': 0,
#  'Hunt for the Wilderpeople': 2500000,
#  'Phantoms': 0,
#  'My Best Friend Is a Vampire': 0,
#  "Babette's Feast": 0,
#  'Ricochet': 0,
#  'Madeline': 20000000,
#  'The Little Hours': 0,
#  'In the Shadow of Kilimanjaro': 0,
#  'Revenge of the Nerds II: Nerds in Paradise': 0,
#  'Hyenas': 0,
#  'My Life Without Me': 2500000,
#  'Genius': 0,
#  'Hardbodies': 1995000,
#  'Cyrano de Bergerac': 0,
#  'Brassed Off': 0,
#  'Croupier': 0,
#  'Black Friday': 0,
#  'The Wind': 0,
#  'The Unholy': 10000000,
#  'Hammett': 0,
#  'Fighting': 0,
#  'Beauty Shop': 25000000,
#  'Enemy': 0,
#  'Fever Pitch': 0,
#  'Princess Caraboo': 0,
#  'Bāhubali 2: The Conclusion': 31000000,
#  'Cops & Robbersons': 0,
#  'The Final Cut': 0,
#  'The Dead': 0,
#  'Bajirao Mastani': 19500000,
#  'Lassie': 0,
#  'Climax': 2900000,
#  "That's Show Business": 0,
#  'Warning Sign': 707990,
#  'The Sunchaser': 0,
#  'Infinity': 0,
#  'Altered States': 15000000,
#  'Hero and the Terror': 0,
#  'Eternity and a Day': 0,
#  'Short Time': 0,
#  'Read My Lips': 0,
#  'Sunshine': 50000000,
#  'The Boy in Blue': 0,
#  'Ode to Joy': 0,
#  'The Muppets Take Manhattan': 8000000,
#  'Sweetie': 0,
#  'More to Life': 7000,
#  'Shoot the Piano Player': 0,
#  'My Summer of Love': 0,
#  'Tumbledown': 0,
#  'Loving Couples': 0,
#  'Link': 0,
#  'The Lover': 0,
#  'My Week with Marilyn': 6400000,
#  'Back Roads': 0,
#  'The Presidio': 0,
#  'The Wolf at the Door': 0,
#  'Oscar and Lucinda': 16000000,
#  'Dear White People': 1000000,
#  'Swimming Pool': 7800000,
#  'Turbo Kid': 0,
#  'The Bay Boy': 0,
#  'Julia(s)': 0,
#  'Tuff Turf': 0,
#  "Coal Miner's Daughter": 15000000,
#  'Parting Glances': 0,
#  'The Babe': 0,
#  'Lore': 0,
#  'V.I. Warshawski': 0,
#  'Dream Lover': 0,
#  'Scanners': 4100000,
#  'Absolute Beginners': 0,
#  'Days of Being Wild': 0,
#  'The Inevitable Defeat of Mister & Pete': 0,
#  'Bread and Tulips': 0,
#  'A Little Sex': 0,
#  'Guilty of Romance': 0,
#  'Little Manhattan': 385373,
#  'Goon': 0,
#  'Dancing at the Blue Iguana': 0,
#  'When Father Was Away on Business': 0,
#  'The Cook, the Thief, His Wife & Her Lover': 2300000,
#  'The Sea Inside': 12806000,
#  'Tyrannosaur': 0,
#  'Happy-Go-Lucky': 0,
#  'CJ7': 0,
#  "A Midsummer Night's Sex Comedy": 0,
#  'Jack Mimoun & the Secrets of Val Verde': 14470000,
#  'Art of Love': 0,
#  'A Night in Heaven': 0,
#  'The Real McCoy': 0,
#  "The Men's Club": 0,
#  'The Rider': 0,
#  'The Jane Austen Book Club': 0,
#  'Spring, Summer, Fall, Winter... and Spring': 0,
#  'The Challenge': 0,
#  'Straight Talk': 0,
#  'Shaun of the Dead': 6100000,
#  "Sarah's Key": 10000000,
#  'Kuch Kuch Hota Hai': 2420000,
#  'Goat': 0,
#  'The Double Life of Véronique': 0,
#  'A Taxi Driver': 12820005,
#  'On Golden Pond': 15000000,
#  'Fighting Back': 0,
#  'Submarine': 0,
#  'Where Angels Fear to Tread': 0,
#  'After.Life': 4500000,
#  'The Great Beauty': 9200000,
#  'Gringo': 0,
#  'Twentynine Palms': 0,
#  'Afternoon Delight': 0,
#  'Three for the Road': 0,
#  'The Girls from China': 0,
#  'Leap of Faith': 20000000,
#  'Aniara': 0,
#  'Threesome': 0,
#  'Police Academy 3: Back in Training': 12000000,
#  'Malcolm': 640000,
#  'Big Top Pee-wee': 0,
#  'Love Crime': 0,
#  'Jane Eyre': 13000000,
#  'Fat Girl': 0,
#  'Mysterious Skin': 0,
#  "My Wife's Sister": 0,
#  'Black Moon Rising': 0,
#  'Edge of Sanity': 0,
#  'Revolver': 27000000,
#  'An American Rhapsody': 0,
#  "Detective Conan: The Private Eyes' Requiem": 0,
#  'Somersault': 0,
#  'Castaway': 0,
#  'The Fighting Preacher': 0,
#  'Control': 6800000,
#  'Miss Firecracker': 0,
#  'All of Me': 0,
#  'By Light of Desert Night': 0,
#  'Mississippi Masala': 8000000,
#  'The Killing of a Sacred Deer': 3000000,
#  'Still Smokin': 0,
#  'Love by Drowning': 0,
#  'Just One of the Guys': 11500000,
#  'Bad Medicine': 0,
#  "It's All About Love": 0,
#  'Human Nature': 6000000,
#  'The Old Man and the Sea': 0,
#  "'71": 11000000,
#  'The Hit': 0,
#  'Ned Kelly': 0,
#  'Barfi!': 4437508,
#  'I Want You': 0,
#  'Misunderstood': 10000000,
#  'Caro diario': 0,
#  'Lila Says': 0,
#  '2 Days in the Valley': 0,
#  'Them That Follow': 0,
#  'Reversal of Fortune': 0,
#  'High-Rise': 0,
#  'Nutcracker': 0,
#  'Batla House': 0,
#  'The Hole in the Ground': 0,
#  'Train to Busan': 8500000,
#  'Return of the Living Dead III': 2000000,
#  'Junglee': 0,
#  'The Discreet': 0,
#  'Jean de Florette': 4940939,
#  'Low Blow': 0,
#  'Show Me Love': 0,
#  'A Guide to Recognizing Your Saints': 0,
#  'Fatso': 0,
#  'Wild Hogs': 0,
#  'Along with the Gods: The Last 49 Days': 18300000,
#  'Professor Marston and the Wonder Women': 7000000,
#  '45 Years': 0,
#  'Boyfriends and Girlfriends': 0,
#  'Jamon Jamon': 0,
#  'Mustang': 1300000,
#  'Charlie Says': 0,
#  'Song to Song': 10000000,
#  'Boxing Helena': 0,
#  'Not of This Earth': 210000,
#  "L'ennui": 0,
#  'The Buddy System': 0,
#  'Lost and Delirious': 0,
#  'Loverboy': 0,
#  'The Puppet Masters': 15000000,
#  'Disorganized Crime': 0,
#  'Into the White': 0,
#  'Grand Canyon': 0,
#  'Code Name: Emerald': 0,
#  'The Sentinel': 0,
#  'The Trip to Bountiful': 0,
#  'Leaving Normal': 0,
#  'The Host': 44000000,
#  'Major Payne': 0,
#  'The Only Living Boy in New York': 0,
#  '24 Hours to Live': 0,
#  'The Hottie & The Nottie': 0,
#  'The Wizard of Oz': 2777000,
#  'Miles from Home': 0,
#  'Cashback': 0,
#  'The Wife': 7000000,
#  '8 Women': 8000000,
#  'Wicked Stepmother': 2500000,
#  'The Salvation': 10500000,
#  'Kamikaze 1989': 0,
#  'Under the Shadow': 0,
#  'Storm Boy': 0,
#  'High Art': 0,
#  '3 Ninjas: High Noon at Mega Mountain': 0,
#  'Like Someone in Love': 0,
#  'GOMORRAH': 5000,
#  'Human Traffic': 600000,
#  'Youngblood': 0,
#  'Hey Ram': 3900000,
#  'Feds': 0,
#  'Sonny': 0,
#  'Raise the Red Lantern': 1000000,
#  'Wild Orchid': 7000000,
#  '#Blue_Whale': 0,
#  'JCVD': 6000000,
#  'The Assault': 0,
#  'The Girl in a Swing': 0,
#  'Richard Pryor: Here and Now': 0,
#  "Breakin' 2: Electric Boogaloo": 0,
#  'Spread': 0,
#  'Strictly Ballroom': 3000000,
#  'Came a Hot Friday': 0,
#  'In a Valley of Violence': 0,
#  'To Love, Honor and Obey': 0,
#  'A Room for Romeo Brass': 0,
#  'Heart of Midnight': 5000000,
#  'Making Love': 0,
#  'Knight of Cups': 0,
#  'Violent Cop': 0,
#  'Mr. Mom': 0,
#  'Win Win': 10831173,
#  'A Bigger Splash': 0,
#  "Men Don't Leave": 0,
#  'The Keeping Room': 0,
#  'Because I Said So': 0,
#  'Hotel Mumbai': 25000000,
#  'Laws of Gravity': 38000,
#  'Out of Bounds': 0,
#  'Bully': 0,
#  'Nobody Knows': 0,
#  'The Last Mimzy': 0,
#  'Heavyweights': 10000000,
#  'Biggles': 0,
#  'Once Were Warriors': 950000,
#  'Close-Up': 0,
#  'Oxford Blues': 0,
#  'Iron Will': 0,
#  "Comin' at Ya!": 0,
#  'Duet for One': 0,
#  'Saaho': 51000000,
#  'Liberty Heights': 0,
#  'Crazy People': 0,
#  ...}

# %%
# Find all the unqiue values in original_df
existing_movies = set(original_df['name'])

# Iterate through update to remove any movie names not in the movies.csv
update_filtered = {key: budget for key, budget in update.items() if key in existing_movies}

# Check for Null values in original and update the value using the budget of update_filtered
# If the budget value in update_filtered is 0, then ignore the value and keep Null
for key, budget in update_filtered.items():
    if budget > 0:
        original_df.loc[(original_df['name'] == key) & (original_df['budget'].isnull()), 'budget'] = budget
    else:
        continue

# %%
# Write a new Csv called Movies_updated.csv
original_df.to_csv('Movies_updated.csv')
