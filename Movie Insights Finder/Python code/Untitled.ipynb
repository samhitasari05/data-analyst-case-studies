# %% [markdown]
# # Merging App Movie CSV Files

# %%
#import libraries
import pandas as pd

# %%
# read in the 3 csv files (Amazon, Netflix and Disney)

amazon = pd.read_csv('D:\Learning\Portfolio\Movie Finder\Movie Files\Amazon\\titles.csv',encoding = "UTF-16 Le")

disney = pd.read_csv('D:\Learning\Portfolio\Movie Finder\Movie Files\Disney+\\titles.csv',encoding = "UTF-16 Le")

netflix = pd.read_csv('D:\Learning\Portfolio\Movie Finder\Movie Files\\Netflix\\titles.csv',encoding = "UTF-16 Le")

# %%
amazon
# Out:
#              id      Platform                            title   type  \
# 0       ts20945  Amazon Prime                The Three Stooges   SHOW
# 1       tm19248  Amazon Prime                      The General  MOVIE
# 2       tm82253  Amazon Prime      The Best Years of Our Lives  MOVIE
# 3       tm83884  Amazon Prime                  His Girl Friday  MOVIE
# 4       tm56584  Amazon Prime                In a Lonely Place  MOVIE
# ...         ...           ...                              ...    ...
# 9866   tm510327  Amazon Prime                     Lily Is Here  MOVIE
# 9867  tm1079144  Amazon Prime  Jay Nog: Something from Nothing  MOVIE
# 9868   tm847725  Amazon Prime                          Chasing  MOVIE
# 9869  tm1054116  Amazon Prime                         Baikunth  MOVIE
# 9870   ts275838  Amazon Prime                 Waking Up Eighty   SHOW
#
#                                             description  release_year  \
# 0     The Three Stooges were an American vaudeville ...          1934
# 1     During America’s Civil War, Union spies steal ...          1926
# 2     It's the hope that sustains the spirit of ever...          1946
# 3     Hildy, the journalist former wife of newspaper...          1940
# 4     An aspiring actress begins to suspect that her...          1950
# ...                                                 ...           ...
# 9866  Dallas and heroin have one thing in common: Du...          2021
# 9867  Something From Nothing takes you on a stand-up...          2021
# 9868  A cop from Chennai sets out to nab a dreaded d...          2021
# 9869  This story is about prevalent caste problem, e...          2021
# 9870  Kara Stewart, 16, is fed up with just about ev...          2021
#
#      age_certification  runtime  \
# 0                TV-PG       19
# 1                  NaN       78
# 2                  NaN      171
# 3                  NaN       92
# 4                  NaN       94
# ...                ...      ...
# 9866               NaN       93
# 9867               NaN       55
# 9868               NaN      116
# 9869               NaN       72
# 9870               NaN       10
#
#                                                  genres production_countries  \
# 0     ['comedy', 'family', 'animation', 'action', 'f...               ['US']
# 1     ['action', 'drama', 'war', 'western', 'comedy'...               ['US']
# 2                           ['romance', 'war', 'drama']               ['US']
# 3                        ['comedy', 'drama', 'romance']               ['US']
# 4                      ['thriller', 'drama', 'romance']               ['US']
# ...                                                 ...                  ...
# 9866                                          ['drama']               ['US']
# 9867                                         ['comedy']               ['US']
# 9868                                          ['crime']               ['IN']
# 9869                                ['family', 'drama']                   []
# 9870                                          ['drama']                   []
#
#       seasons     imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0        26.0   tt0850645         8.6      1092.0           15.424         7.6
# 1         NaN   tt0017925         8.2     89766.0            8.647         8.0
# 2         NaN   tt0036868         8.1     63026.0            8.435         7.8
# 3         NaN   tt0032599         7.8     57835.0           11.270         7.4
# 4         NaN   tt0042593         7.9     30924.0            8.273         7.6
# ...       ...         ...         ...         ...              ...         ...
# 9866      NaN   tt7672388         5.3        20.0            1.406         NaN
# 9867      NaN  tt15041600         NaN         NaN            0.600         NaN
# 9868      NaN         NaN         NaN         NaN            1.960         NaN
# 9869      NaN  tt14331982         8.4        49.0            0.645         NaN
# 9870      1.0  tt13542552         NaN         NaN              NaN         NaN
#
# [9871 rows x 16 columns]

# %%
netflix
# Out:
#              id Platform                                title   type  \
# 0      ts300399  Netflix  Five Came Back: The Reference Films   SHOW
# 1       tm82169  Netflix                                Rocky  MOVIE
# 2       tm17823  Netflix                               Grease  MOVIE
# 3      tm191099  Netflix                            The Sting  MOVIE
# 4       tm69975  Netflix                             Rocky II  MOVIE
# ...         ...      ...                                  ...    ...
# 6114  tm1303784  Netflix                        عبود في البيت  MOVIE
# 6115  tm1260999  Netflix                              Sweetie  MOVIE
# 6116  tm1310286  Netflix            Sommore: Queen Chandelier  MOVIE
# 6117  tm1072700  Netflix                         All Na Vibes  MOVIE
# 6118   tm561709  Netflix                      Going to Heaven  MOVIE
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 1     When world heavyweight boxing champion, Apollo...          1976
# 2     Australian good girl Sandy and greaser Danny f...          1978
# 3     A novice con man teams up with an acknowledged...          1973
# 4     After Rocky goes the distance with champ Apoll...          1979
# ...                                                 ...           ...
# 6114  Two young boys must work together to stop robb...          2023
# 6115  ‘Theatre is my life,’ Yıldız Kenter admits in ...          2023
# 6116  This Queen of Comedy shines as she takes the s...          2023
# 6117  The lives of three teenagers and a hit-man int...          2023
# 6118  A story about young boy sultan, 11 years old l...          2023
#
#      age_certification  runtime                                 genres  \
# 0                TV-MA       51                      ['documentation']
# 1                   PG      119                     ['drama', 'sport']
# 2                   PG      110                  ['romance', 'comedy']
# 3                   PG      129  ['crime', 'drama', 'comedy', 'music']
# 4                   PG      119                     ['drama', 'sport']
# ...                ...      ...                                    ...
# 6114               NaN       81                   ['family', 'comedy']
# 6115               NaN      120                      ['documentation']
# 6116               NaN       69                             ['comedy']
# 6117               NaN       80                              ['drama']
# 6118               NaN       90                             ['family']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes  \
# 0                  ['US']      1.0         NaN         NaN         NaN
# 1                  ['US']      NaN   tt0075148         8.1    588100.0
# 2                  ['US']      NaN   tt0077631         7.2    283316.0
# 3                  ['US']      NaN   tt0070735         8.3    266738.0
# 4                  ['US']      NaN   tt0079817         7.3    216307.0
# ...                   ...      ...         ...         ...         ...
# 6114               ['KW']      NaN         NaN         NaN         NaN
# 6115               ['TR']      NaN  tt26349328         7.9       209.0
# 6116               ['US']      NaN  tt21033382         6.1        91.0
# 6117               ['NG']      NaN  tt14922926         5.2        18.0
# 6118               ['AE']      NaN   tt4623222         7.0        40.0
#
#       tmdb_popularity  tmdb_score
# 0               0.601         NaN
# 1             106.361       7.782
# 2              33.160       7.406
# 3              24.616       8.020
# 4              75.699       7.246
# ...               ...         ...
# 6114            3.351       2.000
# 6115            2.450       7.200
# 6116            1.960         NaN
# 6117            1.357       4.000
# 6118              NaN         NaN
#
# [6119 rows x 16 columns]

# %%
disney
# Out:
#              id Platform                                   title   type  \
# 0       tm89464  Disney+                  Miracle on 34th Street  MOVIE
# 1       tm61729  Disney+  The Adventures of Ichabod and Mr. Toad  MOVIE
# 2       tm61052  Disney+                              Cinderella  MOVIE
# 3       tm87946  Disney+                                   Dumbo  MOVIE
# 4       tm74391  Disney+                                Fantasia  MOVIE
# ...         ...      ...                                     ...    ...
# 1848   ts305794  Disney+                         7 Toughest Days   SHOW
# 1849  tm1308301  Disney+                Disney100 | Special Look  MOVIE
# 1850  tm1075680  Disney+           World's Most Dangerous Shark?  MOVIE
# 1851  tm1227149  Disney+                             Baby Sharks  MOVIE
# 1852  tm1306624  Disney+             Inside Airport Lost & Found  MOVIE
#
#                                             description  release_year  \
# 0     Kris Kringle, seemingly the embodiment of Sant...          1947
# 1     The Wind in the Willows: Concise version of Ke...          1950
# 2     Cinderella has faith her dreams of a better li...          1950
# 3     Dumbo is a baby elephant born with over-sized ...          1941
# 4     Walt Disney's timeless masterpiece is an extra...          1941
# ...                                                 ...           ...
# 1848  Dwayne Fields grew up around violent gangs and...          2023
# 1849  In 2023, Disney’s 100-year milestone provides ...          2023
# 1850  The Great White has a scary reputation, but Ex...          2023
# 1851  Even the biggest, fastest and fiercest predato...          2023
# 1852                                                NaN          2023
#
#      age_certification  runtime  \
# 0                    G       96
# 1                    G       68
# 2                    G       74
# 3                    G       64
# 4                    G      119
# ...                ...      ...
# 1848             TV-PG       49
# 1849               NaN        1
# 1850             PG-13       44
# 1851                PG       45
# 1852                PG       44
#
#                                                  genres production_countries  \
# 0                         ['family', 'comedy', 'drama']               ['US']
# 1     ['horror', 'fantasy', 'animation', 'family', '...               ['US']
# 2         ['fantasy', 'animation', 'family', 'romance']               ['US']
# 3           ['animation', 'drama', 'family', 'fantasy']               ['US']
# 4           ['animation', 'family', 'fantasy', 'music']               ['US']
# ...                                                 ...                  ...
# 1848             ['reality', 'documentation', 'action']               ['US']
# 1849                                       ['Specials']                   []
# 1850                                  ['documentation']                   []
# 1851                                  ['documentation']               ['US']
# 1852                                       ['Specials']                   []
#
#       seasons     imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0         NaN   tt0039628         7.9     50969.0           23.515       7.388
# 1         NaN   tt0041094         6.9     16502.0           16.194       6.500
# 2         NaN   tt0042332         7.3    164292.0           93.547       7.035
# 3         NaN   tt0033563         7.2    135045.0           54.265       6.999
# 4         NaN   tt0032455         7.7     98764.0           43.609       7.382
# ...       ...         ...         ...         ...              ...         ...
# 1848      1.0  tt15257974         7.8        23.0            3.733       2.000
# 1849      NaN         NaN         NaN         NaN            1.960         NaN
# 1850      NaN         NaN         NaN         NaN            1.623         NaN
# 1851      NaN  tt21271008         6.3        19.0            1.501       2.000
# 1852      NaN         NaN         NaN         NaN            0.600         NaN
#
# [1853 rows x 16 columns]

# %%
# Merge the dataframes amazon, netflix
movies = pd.concat([amazon,netflix,disney])

movies
# Out:
#              id      Platform                          title   type  \
# 0       ts20945  Amazon Prime              The Three Stooges   SHOW
# 1       tm19248  Amazon Prime                    The General  MOVIE
# 2       tm82253  Amazon Prime    The Best Years of Our Lives  MOVIE
# 3       tm83884  Amazon Prime                His Girl Friday  MOVIE
# 4       tm56584  Amazon Prime              In a Lonely Place  MOVIE
# ...         ...           ...                            ...    ...
# 1848   ts305794       Disney+                7 Toughest Days   SHOW
# 1849  tm1308301       Disney+       Disney100 | Special Look  MOVIE
# 1850  tm1075680       Disney+  World's Most Dangerous Shark?  MOVIE
# 1851  tm1227149       Disney+                    Baby Sharks  MOVIE
# 1852  tm1306624       Disney+    Inside Airport Lost & Found  MOVIE
#
#                                             description  release_year  \
# 0     The Three Stooges were an American vaudeville ...          1934
# 1     During America’s Civil War, Union spies steal ...          1926
# 2     It's the hope that sustains the spirit of ever...          1946
# 3     Hildy, the journalist former wife of newspaper...          1940
# 4     An aspiring actress begins to suspect that her...          1950
# ...                                                 ...           ...
# 1848  Dwayne Fields grew up around violent gangs and...          2023
# 1849  In 2023, Disney’s 100-year milestone provides ...          2023
# 1850  The Great White has a scary reputation, but Ex...          2023
# 1851  Even the biggest, fastest and fiercest predato...          2023
# 1852                                                NaN          2023
#
#      age_certification  runtime  \
# 0                TV-PG       19
# 1                  NaN       78
# 2                  NaN      171
# 3                  NaN       92
# 4                  NaN       94
# ...                ...      ...
# 1848             TV-PG       49
# 1849               NaN        1
# 1850             PG-13       44
# 1851                PG       45
# 1852                PG       44
#
#                                                  genres production_countries  \
# 0     ['comedy', 'family', 'animation', 'action', 'f...               ['US']
# 1     ['action', 'drama', 'war', 'western', 'comedy'...               ['US']
# 2                           ['romance', 'war', 'drama']               ['US']
# 3                        ['comedy', 'drama', 'romance']               ['US']
# 4                      ['thriller', 'drama', 'romance']               ['US']
# ...                                                 ...                  ...
# 1848             ['reality', 'documentation', 'action']               ['US']
# 1849                                       ['Specials']                   []
# 1850                                  ['documentation']                   []
# 1851                                  ['documentation']               ['US']
# 1852                                       ['Specials']                   []
#
#       seasons     imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0        26.0   tt0850645         8.6      1092.0           15.424         7.6
# 1         NaN   tt0017925         8.2     89766.0            8.647         8.0
# 2         NaN   tt0036868         8.1     63026.0            8.435         7.8
# 3         NaN   tt0032599         7.8     57835.0           11.270         7.4
# 4         NaN   tt0042593         7.9     30924.0            8.273         7.6
# ...       ...         ...         ...         ...              ...         ...
# 1848      1.0  tt15257974         7.8        23.0            3.733         2.0
# 1849      NaN         NaN         NaN         NaN            1.960         NaN
# 1850      NaN         NaN         NaN         NaN            1.623         NaN
# 1851      NaN  tt21271008         6.3        19.0            1.501         2.0
# 1852      NaN         NaN         NaN         NaN            0.600         NaN
#
# [17843 rows x 16 columns]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17843 entries, 0 to 1852
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    17843 non-null  object
#  1   Platform              17843 non-null  object
#  2   title                 17843 non-null  object
#  3   type                  17843 non-null  object
#  4   description           17693 non-null  object
#  5   release_year          17843 non-null  int64
#  6   age_certification     8163 non-null   object
#  7   runtime               17843 non-null  int64
#  8   genres                17843 non-null  object
#  9   production_countries  17843 non-null  object
#  10  seasons               4184 non-null   float64
#  11  imdb_id               16304 non-null  object
#  12  imdb_score            15841 non-null  float64
#  13  imdb_votes            15804 non-null  float64
#  14  tmdb_popularity       17205 non-null  float64
#  15  tmdb_score            15367 non-null  float64
# dtypes: float64(5), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
# Cleaning Genres Data

# Removing the brackets from genres
movies['genres'] = movies['genres'].str.strip('[]')

# Capitalizing each genre
movies['genres'] = movies['genres'].str.title()

# Replacing quotes
movies['genres'] = movies['genres'].str.replace("'",'',regex=True)

# Removing the brackets from production countries
movies['production_countries'] = movies['production_countries'].str.strip('[]')

# Capitalizing type
movies['type'] = movies['type'].str.title()

# %%
movies
# Out:
#              id      Platform                          title   type  \
# 0       ts20945  Amazon Prime              The Three Stooges   Show
# 1       tm19248  Amazon Prime                    The General  Movie
# 2       tm82253  Amazon Prime    The Best Years of Our Lives  Movie
# 3       tm83884  Amazon Prime                His Girl Friday  Movie
# 4       tm56584  Amazon Prime              In a Lonely Place  Movie
# ...         ...           ...                            ...    ...
# 1848   ts305794       Disney+                7 Toughest Days   Show
# 1849  tm1308301       Disney+       Disney100 | Special Look  Movie
# 1850  tm1075680       Disney+  World's Most Dangerous Shark?  Movie
# 1851  tm1227149       Disney+                    Baby Sharks  Movie
# 1852  tm1306624       Disney+    Inside Airport Lost & Found  Movie
#
#                                             description  release_year  \
# 0     The Three Stooges were an American vaudeville ...          1934
# 1     During America’s Civil War, Union spies steal ...          1926
# 2     It's the hope that sustains the spirit of ever...          1946
# 3     Hildy, the journalist former wife of newspaper...          1940
# 4     An aspiring actress begins to suspect that her...          1950
# ...                                                 ...           ...
# 1848  Dwayne Fields grew up around violent gangs and...          2023
# 1849  In 2023, Disney’s 100-year milestone provides ...          2023
# 1850  The Great White has a scary reputation, but Ex...          2023
# 1851  Even the biggest, fastest and fiercest predato...          2023
# 1852                                                NaN          2023
#
#      age_certification  runtime  \
# 0                TV-PG       19
# 1                  NaN       78
# 2                  NaN      171
# 3                  NaN       92
# 4                  NaN       94
# ...                ...      ...
# 1848             TV-PG       49
# 1849               NaN        1
# 1850             PG-13       44
# 1851                PG       45
# 1852                PG       44
#
#                                                  genres production_countries  \
# 0     Comedy, Family, Animation, Action, Fantasy, Ho...                 'US'
# 1         Action, Drama, War, Western, Comedy, European                 'US'
# 2                                   Romance, War, Drama                 'US'
# 3                                Comedy, Drama, Romance                 'US'
# 4                              Thriller, Drama, Romance                 'US'
# ...                                                 ...                  ...
# 1848                     Reality, Documentation, Action                 'US'
# 1849                                           Specials
# 1850                                      Documentation
# 1851                                      Documentation                 'US'
# 1852                                           Specials
#
#       seasons     imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0        26.0   tt0850645         8.6      1092.0           15.424         7.6
# 1         NaN   tt0017925         8.2     89766.0            8.647         8.0
# 2         NaN   tt0036868         8.1     63026.0            8.435         7.8
# 3         NaN   tt0032599         7.8     57835.0           11.270         7.4
# 4         NaN   tt0042593         7.9     30924.0            8.273         7.6
# ...       ...         ...         ...         ...              ...         ...
# 1848      1.0  tt15257974         7.8        23.0            3.733         2.0
# 1849      NaN         NaN         NaN         NaN            1.960         NaN
# 1850      NaN         NaN         NaN         NaN            1.623         NaN
# 1851      NaN  tt21271008         6.3        19.0            1.501         2.0
# 1852      NaN         NaN         NaN         NaN            0.600         NaN
#
# [17843 rows x 16 columns]

# %%
movies.to_csv('Movies.csv', index = False)
